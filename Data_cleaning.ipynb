# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Data Scientist.csv")
df.head(10)
# Out:
#    Unnamed: 0                              company  \
# 0           0                       Microsoft\n4.4
# 1           1  UT Southwestern Medical Center\n4.0
# 2           2                          Notion\n4.9
# 3           3                 CODING DOJO INC\n3.9
# 4           4                          Net2Aspire0
# 5           5                      Ntropy Network0
# 6           6                          PayPal\n4.0
# 7           7      Pomeroy Technologies, LLC.\n2.8
# 8           8                           Delta\n4.3
# 9           9             Booz Allen Hamilton\n4.2
#
#                                            job title        location  \
# 0                           Data & Applied Scientist     Redmond, WA
# 1        Data Scientist or Bioinformatician (remote)          Remote
# 2                             Data Scientist, Growth    New York, NY
# 3    Coding Bootcamp Data Scientist (Virtual/Remote)          Remote
# 4                                 Jr. Data Scientist          Remote
# 5                                     Data Scientist          Remote
# 6                                     Data Scientist     Chicago, IL
# 7                                     Data Scientist          Remote
# 8  Associate Data Scientist, Operations Decision ...     Atlanta, GA
# 9             Tech Excellence Data Scientist, Junior  Alexandria, VA
#
#                                      job description      salary estimate  \
# 0  Microsoft 365 is a key part of the company’s c...  $123,486 /yr (est.)
# 1  Center Information:\nThe Quantitative Biomedic...   $93,500 /yr (est.)
# 2  About Us:\nWe're on a mission to make it possi...  $137,853 /yr (est.)
# 3  This is a full-time, virtual/remote position i...                  NaN
# 4   Apply Statistical and Machine Learning metho...   $72,500 /yr (est.)
# 5  Over the last few decades, technological innov...  $155,000 /yr (est.)
# 6  At PayPal (NASDAQ: PYPL), we believe that ever...  $109,837 /yr (est.)
# 7  Data Scientist--Remote\n(company is based in t...  $110,000 /yr (est.)
# 8  United States, Georgia, Atlanta\nOps Control\n...  $103,268 /yr (est.)
# 9  The Challenge:\nAre you excited at the prospec...  $102,817 /yr (est.)
#
#              company_size                    company_type  \
# 0        10000+ Employees                Company - Public
# 1        10000+ Employees                        Hospital
# 2    201 to 500 Employees               Company - Private
# 3     51 to 200 Employees               Company - Private
# 4                 Unknown                Company - Public
# 5       1 to 50 Employees               Company - Private
# 6        10000+ Employees                Company - Public
# 7  1001 to 5000 Employees  Subsidiary or Business Segment
# 8        10000+ Employees                Company - Public
# 9        10000+ Employees                Company - Public
#
#                company_sector                         company_industry  \
# 0      Information Technology            Computer Hardware Development
# 1                  Healthcare         Health Care Services & Hospitals
# 2      Information Technology  Enterprise Software & Network Solutions
# 3                   Education            Education & Training Services
# 4                         NaN                                      NaN
# 5                         NaN                                      NaN
# 6      Information Technology                  Internet & Web Services
# 7      Information Technology  Information Technology Support Services
# 8  Transportation & Logistics  Airlines, Airports & Air Transportation
# 9     Management & Consulting                      Business Consulting
#
#    company_founded           company_revenue
# 0           1975.0        $10+ billion (USD)
# 1           1943.0    $1 to $5 billion (USD)
# 2           2016.0  Unknown / Non-Applicable
# 3           2013.0   $5 to $25 million (USD)
# 4              NaN  Unknown / Non-Applicable
# 5              NaN  Unknown / Non-Applicable
# 6           1998.0        $10+ billion (USD)
# 7           1982.0  Unknown / Non-Applicable
# 8           1928.0        $10+ billion (USD)
# 9           1914.0   $5 to $10 billion (USD)

# %% [markdown]
# 1-Seperate the rating from the company name
#
# 2-parsing Job Describtion

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        720 non-null    int64
#  1   company           720 non-null    object
#  2   job title         720 non-null    object
#  3   location          720 non-null    object
#  4   job description   720 non-null    object
#  5   salary estimate   545 non-null    object
#  6   company_size      666 non-null    object
#  7   company_type      666 non-null    object
#  8   company_sector    534 non-null    object
#  9   company_industry  534 non-null    object
#  10  company_founded   485 non-null    float64
#  11  company_revenue   666 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 67.6+ KB

# %%
df=df[df['salary estimate'].notna()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 545 entries, 0 to 719
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        545 non-null    int64
#  1   company           545 non-null    object
#  2   job title         545 non-null    object
#  3   location          545 non-null    object
#  4   job description   545 non-null    object
#  5   salary estimate   545 non-null    object
#  6   company_size      494 non-null    object
#  7   company_type      494 non-null    object
#  8   company_sector    384 non-null    object
#  9   company_industry  384 non-null    object
#  10  company_founded   342 non-null    float64
#  11  company_revenue   494 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 55.4+ KB

# %%
df["salary estimate"]=df['salary estimate'].apply(lambda x : x.split("(")[0])
df["salary estimate"]=df['salary estimate'].apply(lambda x : x.replace('$',''))
df['hourly']=df['salary estimate'].apply(lambda x:1 if 'hr' in x else 0)
df["salary estimate"]=df['salary estimate'].apply(lambda x : float(x.split("/")[0].replace(',','')))



df.head()
# Out:
#    Unnamed: 0                              company  \
# 0           0                       Microsoft\n4.4
# 1           1  UT Southwestern Medical Center\n4.0
# 2           2                          Notion\n4.9
# 4           4                          Net2Aspire0
# 5           5                      Ntropy Network0
#
#                                      job title      location  \
# 0                     Data & Applied Scientist   Redmond, WA
# 1  Data Scientist or Bioinformatician (remote)        Remote
# 2                       Data Scientist, Growth  New York, NY
# 4                           Jr. Data Scientist        Remote
# 5                               Data Scientist        Remote
#
#                                      job description  salary estimate  \
# 0  Microsoft 365 is a key part of the company’s c...         123486.0
# 1  Center Information:\nThe Quantitative Biomedic...          93500.0
# 2  About Us:\nWe're on a mission to make it possi...         137853.0
# 4   Apply Statistical and Machine Learning metho...          72500.0
# 5  Over the last few decades, technological innov...         155000.0
#
#            company_size       company_type          company_sector  \
# 0      10000+ Employees   Company - Public  Information Technology
# 1      10000+ Employees           Hospital              Healthcare
# 2  201 to 500 Employees  Company - Private  Information Technology
# 4               Unknown   Company - Public                     NaN
# 5     1 to 50 Employees  Company - Private                     NaN
#
#                           company_industry  company_founded  \
# 0            Computer Hardware Development           1975.0
# 1         Health Care Services & Hospitals           1943.0
# 2  Enterprise Software & Network Solutions           2016.0
# 4                                      NaN              NaN
# 5                                      NaN              NaN
#
#             company_revenue  hourly
# 0        $10+ billion (USD)       0
# 1    $1 to $5 billion (USD)       0
# 2  Unknown / Non-Applicable       0
# 4  Unknown / Non-Applicable       0
# 5  Unknown / Non-Applicable       0

# %%
df[df['hourly']==1]
# Out:
#      Unnamed: 0                                            company  \
# 17           17                                 STEPS TALENT, LLC0
# 27           27                                Mican Technologies0
# 35           35                                      Infoserv LLC0
# 44           44                                  Talent Group\n1.0
# 52           52                                    Violet Ink\n4.2
# 55           55                           ADG Tech Consulting\n4.2
# 64           64                          Zenotis Technologies INC0
# 70           70                                  Apptrics LLC\n5.0
# 72           72                              BASF Corporation\n4.1
# 74           74                     OPENMIND TECHNOLOGIES INC\n4.2
# 104         104                                       Radiant\n3.7
# 106         106                                     Match Inc\n3.0
# 115         115                           Core Alliance Group Inc0
# 120         120                                       Radiant\n3.7
# 122         122                           Core Alliance Group Inc0
# 135         135                                    Braintrust\n4.6
# 147         147                                           Hireups0
# 148         148                                        Aptara\n3.4
# 158         158                             Devcare Solutions\n3.6
# 163         163                                      S3vision Inc0
# 177         177                                   Altak Group\n2.0
# 179         179  Artificial Intelligence Labs at the American A...
# 198         198                                 STEPS TALENT, LLC0
# 202         202                                Mican Technologies0
# 228         228                                 STEPS TALENT, LLC0
# 232         232                                Mican Technologies0
# 262         262                                Mican Technologies0
# 288         288                                 STEPS TALENT, LLC0
# 292         292                                Mican Technologies0
# 318         318                                 STEPS TALENT, LLC0
# 322         322                                Mican Technologies0
# 348         348                                 STEPS TALENT, LLC0
# 352         352                                Mican Technologies0
# 376         376                                 STEPS TALENT, LLC0
# 388         388                                Mican Technologies0
# 406         406                                 STEPS TALENT, LLC0
# 418         418                                Mican Technologies0
# 436         436                                 STEPS TALENT, LLC0
# 448         448                                Mican Technologies0
# 466         466                                 STEPS TALENT, LLC0
# 496         496                                 STEPS TALENT, LLC0
# 526         526                                 STEPS TALENT, LLC0
# 556         556                                 STEPS TALENT, LLC0
# 586         586                                 STEPS TALENT, LLC0
# 616         616                                 STEPS TALENT, LLC0
# 646         646                                 STEPS TALENT, LLC0
# 681         681                                 STEPS TALENT, LLC0
# 711         711                                 STEPS TALENT, LLC0
#
#                                              job title         location  \
# 17          Data Scientist - 3 positions - 100% remote           Remote
# 27                                  Data Scientist(W2)           Remote
# 35                                      Data Scientist           Remote
# 44                     Data scientist@ Remote Contract           Remote
# 52                                      Data Scientist           Remote
# 55                                      Data Scientist           Remote
# 64                                      Data Scientist           Remote
# 70                                      Data Scientist           Remote
# 72                    Data Scientist, Machine Learning  Morrisville, NC
# 74   (Machine Learning / Python) Data Scientist :: ...           Remote
# 104                     Data scientist/Image Analytics           Remote
# 106                                     Data Scientist           Remote
# 115  Data Scientist ! Remote_ Looking for W2 Consul...           Remote
# 120                     Data scientist/Image Analytics           Remote
# 122  Data Scientist ! Remote_ Looking for W2 Consul...           Remote
# 135                                      Data Engineer           Remote
# 147                                     Data Scientist           Remote
# 148                                     Data Scientist       Pomona, CA
# 158                 Data Scientist (healthcare domain)           Remote
# 163                                     Data Scientist           Remote
# 177                                Lead Data Scientist           Remote
# 179  Data Scientist / Engineer for Digital Health (...           Remote
# 198         Data Scientist - 3 positions - 100% remote           Remote
# 202                                 Data Scientist(W2)           Remote
# 228         Data Scientist - 3 positions - 100% remote           Remote
# 232                                 Data Scientist(W2)           Remote
# 262                                 Data Scientist(W2)           Remote
# 288         Data Scientist - 3 positions - 100% remote           Remote
# 292                                 Data Scientist(W2)           Remote
# 318         Data Scientist - 3 positions - 100% remote           Remote
# 322                                 Data Scientist(W2)           Remote
# 348         Data Scientist - 3 positions - 100% remote           Remote
# 352                                 Data Scientist(W2)           Remote
# 376         Data Scientist - 3 positions - 100% remote           Remote
# 388                                 Data Scientist(W2)           Remote
# 406         Data Scientist - 3 positions - 100% remote           Remote
# 418                                 Data Scientist(W2)           Remote
# 436         Data Scientist - 3 positions - 100% remote           Remote
# 448                                 Data Scientist(W2)           Remote
# 466         Data Scientist - 3 positions - 100% remote           Remote
# 496         Data Scientist - 3 positions - 100% remote           Remote
# 526         Data Scientist - 3 positions - 100% remote           Remote
# 556         Data Scientist - 3 positions - 100% remote           Remote
# 586         Data Scientist - 3 positions - 100% remote           Remote
# 616         Data Scientist - 3 positions - 100% remote           Remote
# 646         Data Scientist - 3 positions - 100% remote           Remote
# 681         Data Scientist - 3 positions - 100% remote           Remote
# 711         Data Scientist - 3 positions - 100% remote           Remote
#
#                                        job description  salary estimate  \
# 17   We are looking to hire 3 Data Scientists to wo...            65.00
# 27   Data Scientist Remote Long Term Contract REQUI...            62.50
# 35   Only W2 candidates right now we are unable to ...            32.50
# 44   JD:\nExperienced data scientist with hands-on ...            40.35
# 52   Job Description :\nMini 10 + Years of experien...            65.00
# 55   Position: Mid-level AI/Machine Learning Engine...            60.00
# 64   A Data Scientist is responsible for developing...            44.85
# 70   Job Title : Lead Data Scientist\nDuration: 12+...            95.00
# 72   JOB OVERVIEW\nAre you a Data Scientist with si...            50.00
# 74   Skills & Experience: *\n*\nBachelor’s degree i...            95.00
# 104  Location: 100% REMOTE\nDuration- 6 months\nPay...            85.00
# 106  Job Title : Data Scientist\nLocation : San Fra...            95.00
# 115  Looking For W2 Consultants\nHello All,\nHope y...            52.50
# 120  Location: 100% REMOTE\nDuration- 6 months\nPay...            85.00
# 122  Looking For W2 Consultants\nHello All,\nHope y...            52.50
# 135  This is a W2/Freelance role (40 hours a week)\...            85.00
# 147  Data ScientistHireups Inc. – Remote\nResearch ...            70.00
# 148  Title: Technical Specialist / Data Scientist\n...            28.14
# 158  Job title : Data scientist\nDuration : 1+ year...            62.50
# 163  Job Description\nJob Title: Data Scientist\nLo...            57.50
# 177  We are looking for a Data Scientist to analyze...            77.50
# 179  This is a part-time and remote job only for da...            90.00
# 198  We are looking to hire 3 Data Scientists to wo...            65.00
# 202  Data Scientist Remote Long Term Contract REQUI...            62.50
# 228  We are looking to hire 3 Data Scientists to wo...            65.00
# 232  Data Scientist Remote Long Term Contract REQUI...            62.50
# 262  Data Scientist Remote Long Term Contract REQUI...            62.50
# 288  We are looking to hire 3 Data Scientists to wo...            65.00
# 292  Data Scientist Remote Long Term Contract REQUI...            62.50
# 318  We are looking to hire 3 Data Scientists to wo...            65.00
# 322  Data Scientist Remote Long Term Contract REQUI...            62.50
# 348  We are looking to hire 3 Data Scientists to wo...            65.00
# 352  Data Scientist Remote Long Term Contract REQUI...            62.50
# 376  We are looking to hire 3 Data Scientists to wo...            65.00
# 388  Data Scientist Remote Long Term Contract REQUI...            62.50
# 406  We are looking to hire 3 Data Scientists to wo...            65.00
# 418  Data Scientist Remote Long Term Contract REQUI...            62.50
# 436  We are looking to hire 3 Data Scientists to wo...            65.00
# 448  Data Scientist Remote Long Term Contract REQUI...            62.50
# 466  We are looking to hire 3 Data Scientists to wo...            65.00
# 496  We are looking to hire 3 Data Scientists to wo...            65.00
# 526  We are looking to hire 3 Data Scientists to wo...            65.00
# 556  We are looking to hire 3 Data Scientists to wo...            65.00
# 586  We are looking to hire 3 Data Scientists to wo...            65.00
# 616  We are looking to hire 3 Data Scientists to wo...            65.00
# 646  We are looking to hire 3 Data Scientists to wo...            65.00
# 681  We are looking to hire 3 Data Scientists to wo...            65.00
# 711  We are looking to hire 3 Data Scientists to wo...            65.00
#
#                 company_size                    company_type  \
# 17                       NaN                             NaN
# 27                       NaN                             NaN
# 35      201 to 500 Employees               Company - Private
# 44         1 to 50 Employees                Company - Public
# 52         1 to 50 Employees                Company - Public
# 55       51 to 200 Employees               Company - Private
# 64                   Unknown                Company - Public
# 70                   Unknown                Company - Public
# 72     501 to 1000 Employees               Company - Private
# 74                   Unknown         Private Practice / Firm
# 104     201 to 500 Employees               Company - Private
# 106        1 to 50 Employees               Company - Private
# 115                      NaN                             NaN
# 120     201 to 500 Employees               Company - Private
# 122                      NaN                             NaN
# 135                  Unknown               Company - Private
# 147        1 to 50 Employees                Company - Public
# 148  5001 to 10000 Employees  Subsidiary or Business Segment
# 158      51 to 200 Employees               Company - Private
# 163                  Unknown                Company - Public
# 177        1 to 50 Employees               Company - Private
# 179                      NaN                             NaN
# 198                      NaN                             NaN
# 202                      NaN                             NaN
# 228                      NaN                             NaN
# 232                      NaN                             NaN
# 262                      NaN                             NaN
# 288                      NaN                             NaN
# 292                      NaN                             NaN
# 318                      NaN                             NaN
# 322                      NaN                             NaN
# 348                      NaN                             NaN
# 352                      NaN                             NaN
# 376                      NaN                             NaN
# 388                      NaN                             NaN
# 406                      NaN                             NaN
# 418                      NaN                             NaN
# 436                      NaN                             NaN
# 448                      NaN                             NaN
# 466                      NaN                             NaN
# 496                      NaN                             NaN
# 526                      NaN                             NaN
# 556                      NaN                             NaN
# 586                      NaN                             NaN
# 616                      NaN                             NaN
# 646                      NaN                             NaN
# 681                      NaN                             NaN
# 711                      NaN                             NaN
#
#                  company_sector                         company_industry  \
# 17                          NaN                                      NaN
# 27                          NaN                                      NaN
# 35       Information Technology                     Software Development
# 44        Media & Communication                          Broadcast Media
# 52       Information Technology  Information Technology Support Services
# 55       Information Technology  Information Technology Support Services
# 64                          NaN                                      NaN
# 70       Information Technology  Information Technology Support Services
# 72   Human Resources & Staffing                            HR Consulting
# 74       Information Technology  Enterprise Software & Network Solutions
# 104      Information Technology  Enterprise Software & Network Solutions
# 106       Media & Communication           Advertising & Public Relations
# 115                         NaN                                      NaN
# 120      Information Technology  Enterprise Software & Network Solutions
# 122                         NaN                                      NaN
# 135     Management & Consulting                      Business Consulting
# 147                         NaN                                      NaN
# 148          Financial Services                         Accounting & Tax
# 158      Information Technology  Information Technology Support Services
# 163                         NaN                                      NaN
# 177                         NaN                                      NaN
# 179                         NaN                                      NaN
# 198                         NaN                                      NaN
# 202                         NaN                                      NaN
# 228                         NaN                                      NaN
# 232                         NaN                                      NaN
# 262                         NaN                                      NaN
# 288                         NaN                                      NaN
# 292                         NaN                                      NaN
# 318                         NaN                                      NaN
# 322                         NaN                                      NaN
# 348                         NaN                                      NaN
# 352                         NaN                                      NaN
# 376                         NaN                                      NaN
# 388                         NaN                                      NaN
# 406                         NaN                                      NaN
# 418                         NaN                                      NaN
# 436                         NaN                                      NaN
# 448                         NaN                                      NaN
# 466                         NaN                                      NaN
# 496                         NaN                                      NaN
# 526                         NaN                                      NaN
# 556                         NaN                                      NaN
# 586                         NaN                                      NaN
# 616                         NaN                                      NaN
# 646                         NaN                                      NaN
# 681                         NaN                                      NaN
# 711                         NaN                                      NaN
#
#      company_founded             company_revenue  hourly
# 17               NaN                         NaN       1
# 27               NaN                         NaN       1
# 35            2004.0     $5 to $25 million (USD)       1
# 44               NaN  Less than $1 million (USD)       1
# 52            2007.0    Unknown / Non-Applicable       1
# 55               NaN     $5 to $25 million (USD)       1
# 64               NaN    Unknown / Non-Applicable       1
# 70               NaN    Unknown / Non-Applicable       1
# 72            1999.0   $25 to $100 million (USD)       1
# 74               NaN    Unknown / Non-Applicable       1
# 104           2000.0    Unknown / Non-Applicable       1
# 106              NaN      $1 to $5 million (USD)       1
# 115              NaN                         NaN       1
# 120           2000.0    Unknown / Non-Applicable       1
# 122              NaN                         NaN       1
# 135           2018.0     $5 to $25 million (USD)       1
# 147              NaN    Unknown / Non-Applicable       1
# 148           1988.0  $100 to $500 million (USD)       1
# 158           2005.0    Unknown / Non-Applicable       1
# 163              NaN    Unknown / Non-Applicable       1
# 177              NaN    Unknown / Non-Applicable       1
# 179              NaN                         NaN       1
# 198              NaN                         NaN       1
# 202              NaN                         NaN       1
# 228              NaN                         NaN       1
# 232              NaN                         NaN       1
# 262              NaN                         NaN       1
# 288              NaN                         NaN       1
# 292              NaN                         NaN       1
# 318              NaN                         NaN       1
# 322              NaN                         NaN       1
# 348              NaN                         NaN       1
# 352              NaN                         NaN       1
# 376              NaN                         NaN       1
# 388              NaN                         NaN       1
# 406              NaN                         NaN       1
# 418              NaN                         NaN       1
# 436              NaN                         NaN       1
# 448              NaN                         NaN       1
# 466              NaN                         NaN       1
# 496              NaN                         NaN       1
# 526              NaN                         NaN       1
# 556              NaN                         NaN       1
# 586              NaN                         NaN       1
# 616              NaN                         NaN       1
# 646              NaN                         NaN       1
# 681              NaN                         NaN       1
# 711              NaN                         NaN       1

# %%
df['rating']=df['company'].apply(lambda x: x[-3:] if '\n'in x else 'no rating')
df['company']=df['company'].apply(lambda x: x[:-4] if '\n'in x else x[:-1])

df.head()
# Out:
#    Unnamed: 0                         company  \
# 0           0                       Microsoft
# 1           1  UT Southwestern Medical Center
# 2           2                          Notion
# 4           4                      Net2Aspire
# 5           5                  Ntropy Network
#
#                                      job title      location  \
# 0                     Data & Applied Scientist   Redmond, WA
# 1  Data Scientist or Bioinformatician (remote)        Remote
# 2                       Data Scientist, Growth  New York, NY
# 4                           Jr. Data Scientist        Remote
# 5                               Data Scientist        Remote
#
#                                      job description  salary estimate  \
# 0  Microsoft 365 is a key part of the company’s c...         123486.0
# 1  Center Information:\nThe Quantitative Biomedic...          93500.0
# 2  About Us:\nWe're on a mission to make it possi...         137853.0
# 4   Apply Statistical and Machine Learning metho...          72500.0
# 5  Over the last few decades, technological innov...         155000.0
#
#            company_size       company_type          company_sector  \
# 0      10000+ Employees   Company - Public  Information Technology
# 1      10000+ Employees           Hospital              Healthcare
# 2  201 to 500 Employees  Company - Private  Information Technology
# 4               Unknown   Company - Public                     NaN
# 5     1 to 50 Employees  Company - Private                     NaN
#
#                           company_industry  company_founded  \
# 0            Computer Hardware Development           1975.0
# 1         Health Care Services & Hospitals           1943.0
# 2  Enterprise Software & Network Solutions           2016.0
# 4                                      NaN              NaN
# 5                                      NaN              NaN
#
#             company_revenue  hourly     rating
# 0        $10+ billion (USD)       0        4.4
# 1    $1 to $5 billion (USD)       0        4.0
# 2  Unknown / Non-Applicable       0        4.9
# 4  Unknown / Non-Applicable       0  no rating
# 5  Unknown / Non-Applicable       0  no rating

# %% [markdown]
# #tools of Data Science jobs
#
# - python
# - R Studio
# - Spark
# - aws
# - azure
# - excel
# - tableu

# %%
df['python_yn']=df['job description'].apply(lambda x:1 if "python" in x.lower() else 0)
df['python_yn'].value_counts()
# Out:
# 1    468
# 0     77
# Name: python_yn, dtype: int64

# %%
df['spark_yn']=df['job description'].apply(lambda x:1 if "spark" in x.lower() else 0)
df['spark_yn'].value_counts()
# Out:
# 0    502
# 1     43
# Name: spark_yn, dtype: int64

# %%
df['azure_yn']=df['job description'].apply(lambda x:1 if "azure" in x.lower() else 0)
df['azure_yn'].value_counts()
# Out:
# 0    485
# 1     60
# Name: azure_yn, dtype: int64

# %%
df['aws_yn']=df['job description'].apply(lambda x:1 if "aws" in x.lower() else 0)
df['aws_yn'].value_counts()
# Out:
# 0    403
# 1    142
# Name: aws_yn, dtype: int64

# %%
df['excel_yn']=df['job description'].apply(lambda x:1 if "excel" in x.lower() else 0)
df['excel_yn'].value_counts()
# Out:
# 0    392
# 1    153
# Name: excel_yn, dtype: int64

# %%
df['machine_learning_yn']=df['job description'].apply(lambda x:1 if "machine learning" in x.lower() else 0)
df['machine_learning_yn'].value_counts()
# Out:
# 1    433
# 0    112
# Name: machine_learning_yn, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0                         company  \
# 0           0                       Microsoft
# 1           1  UT Southwestern Medical Center
# 2           2                          Notion
# 4           4                      Net2Aspire
# 5           5                  Ntropy Network
#
#                                      job title      location  \
# 0                     Data & Applied Scientist   Redmond, WA
# 1  Data Scientist or Bioinformatician (remote)        Remote
# 2                       Data Scientist, Growth  New York, NY
# 4                           Jr. Data Scientist        Remote
# 5                               Data Scientist        Remote
#
#                                      job description  salary estimate  \
# 0  Microsoft 365 is a key part of the company’s c...         123486.0
# 1  Center Information:\nThe Quantitative Biomedic...          93500.0
# 2  About Us:\nWe're on a mission to make it possi...         137853.0
# 4   Apply Statistical and Machine Learning metho...          72500.0
# 5  Over the last few decades, technological innov...         155000.0
#
#            company_size       company_type          company_sector  \
# 0      10000+ Employees   Company - Public  Information Technology
# 1      10000+ Employees           Hospital              Healthcare
# 2  201 to 500 Employees  Company - Private  Information Technology
# 4               Unknown   Company - Public                     NaN
# 5     1 to 50 Employees  Company - Private                     NaN
#
#                           company_industry  company_founded  \
# 0            Computer Hardware Development           1975.0
# 1         Health Care Services & Hospitals           1943.0
# 2  Enterprise Software & Network Solutions           2016.0
# 4                                      NaN              NaN
# 5                                      NaN              NaN
#
#             company_revenue  hourly     rating  python_yn  spark_yn  azure_yn  \
# 0        $10+ billion (USD)       0        4.4          1         0         0
# 1    $1 to $5 billion (USD)       0        4.0          1         0         0
# 2  Unknown / Non-Applicable       0        4.9          1         0         0
# 4  Unknown / Non-Applicable       0  no rating          0         0         0
# 5  Unknown / Non-Applicable       0  no rating          1         0         0
#
#    aws_yn  excel_yn  machine_learning_yn
# 0       1         0                    1
# 1       0         0                    1
# 2       0         0                    0
# 4       0         0                    1
# 5       1         0                    0

# %%
df=df.drop('Unnamed: 0',axis=1)
df.to_csv("salary_data_cleaned.csv")
